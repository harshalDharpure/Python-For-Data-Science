# %% [markdown]
# ## Input Function

# %% [markdown]
# We use input() function, to get the input from the user

# %% [markdown]
# The input() prompts the user for input and returns what the user entered as a 'String'

# %% [markdown]
# Note : By default, the input() takes input in the string format

# %% [markdown]
# ----

# %%
input()
# Out:
# 444
# '444'

# %%
input("Enter your PIN :")
# Out:
# Enter your PIN :0
# '0'

# %% [markdown]
# ----

# %% [markdown]
# #### We can get the input from user and save it  into a variable

# %%
s = input("Enter your name : ")
# Out:
# Enter your name : rohit

# %%
print(s)
# Out:
# rohit

# %%
print("Enter your city : ")
x = input()
# Out:
# Enter your city :
# delhi

# %%
x
# Out:
# 'delhi'

# %% [markdown]
# ----

# %% [markdown]
# #### Taking multiple inputs from the users

# %%
print("Please enter your name :")
input()
# Out:
# Please enter your name :
# rohit
# 'rohit'

# %%
print("Enter the ID :")
input()
# Out:
# Enter the ID :
# 8899
# '8899'

# %%
print("Enter the ID :")
int(input())
# Out:
# Enter the ID :
# 99
# 99

# %%
print("Enter your marks :")
float(input())
# Out:
# Enter your marks :
# 78
# 78.0

# %% [markdown]
# ---

# %% [markdown]
# #### Mathematical Operations with input()

# %%
print("Enter first number")
a  = int(input())
print("Enter second number")
b = float(input())
print("The sum of a and b is ", a+b)
# Out:
# Enter first number
# 100
# Enter second number
# 200
# The sum of a and b is  300.0

# %% [markdown]
# ----

# %% [markdown]
# ---

# %%
#Additional
a = input("Enter your name : ")
b = int(input("Enter your new ID : "))
print(f'Hi {a}. Your new ID is {b}')
# Out:
# Enter your name : Mr. A
# Enter your new ID : 999
# Hi Mr. A. Your new ID is 999

# %% [markdown]
# ----

# %% [markdown]
# #### More advanced features of Input Function will be covered in the another playlist of the course ( Advanced - Data Analysis with Python )

# %% [markdown]
# ----

# %% [markdown]
# ----

# %% [markdown]
# -----

# %% [markdown]
# ----

# %% [markdown]
# By - Rohit Grewal ( Big-Data Analyst )
